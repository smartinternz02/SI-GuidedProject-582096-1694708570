# %% [markdown]
# # **Name: Gongati Sree Nidhitha Reddy**

# %% [markdown]
# ## Reg.No: 21BCE2409

# %% [markdown]
# # 1. Import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Import Dataset

# %%
ds=pd.read_csv("Titanic-Dataset.csv")
ds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
ds.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ds.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
ds.shape
# Out:
# (891, 12)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
ds.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
ds.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
ds.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
ds.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
ds.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %% [markdown]
# # 3. Handling Null Values

# %%
ds.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
ds.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
ds["Age"].fillna(ds["Age"].mean(),inplace=True)
ds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
ds["Cabin"].fillna(ds["Cabin"].mode()[0],inplace=True)
ds["Embarked"].fillna(ds["Embarked"].mode()[0],inplace=True)
ds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare    Cabin Embarked
# 0        1      0         A/5 21171   7.2500  B96 B98        S
# 1        1      0          PC 17599  71.2833      C85        C
# 2        0      0  STON/O2. 3101282   7.9250  B96 B98        S
# 3        1      0            113803  53.1000     C123        S
# 4        0      0            373450   8.0500  B96 B98        S
# ..     ...    ...               ...      ...      ...      ...
# 886      0      0            211536  13.0000  B96 B98        S
# 887      0      0            112053  30.0000      B42        S
# 888      1      2        W./C. 6607  23.4500  B96 B98        S
# 889      0      0            111369  30.0000     C148        C
# 890      0      0            370376   7.7500  B96 B98        Q
#
# [891 rows x 12 columns]

# %%
ds.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %% [markdown]
# # 4. Data Visualization

# %% [markdown]
# **1. Scatter Plot**

# %%
sns.scatterplot(x="Pclass", y="Fare", data=ds)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# Inference: In the above graph Pclass is taken on x-axis and Fare is taken on y-axis. This is to analize the Fare of different Pclass

# %% [markdown]
# **2. Line Plot**

# %%
sns.lineplot(x="Pclass",y="Survived",data=ds)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# Inference: Line plot with Pclass on x-axis and Survived on y-axis is plotted.

# %% [markdown]
# **3. Distribution Plot**

# %%
sns.distplot(ds["Fare"])
# Out:
# <ipython-input-77-76aa0978ee3c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ds["Fare"])
# <Axes: xlabel='Fare', ylabel='Density'>

# %% [markdown]
# Inference: In this graph x-axis represents Fare  and y-axis represents the probability density. The density of previous Fare increases until 10 and later decreases.

# %% [markdown]
# **4. Relational plot**

# %%
sns.relplot(x="Fare", y="Survived", data=ds, hue="Sex")

# %% [markdown]
# Inference: Relational plot with Fare on x-axis and Survived on y-axis with hue as Sex is plotted. It allows us to visualise how variables on a dataset relate to each other.

# %% [markdown]
# **5. Bar Plot**

# %% [markdown]
# Inference: Bar graph is plotted with not_distracted on x-axis and ins_losses on y-axis

# %%
sns.barplot(data=ds, x="Age",y="Survived",errorbar=None)
sns.figure(figsize(17,8))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-d01b1be0db06> in <cell line: 2>()
#       1 sns.barplot(data=ds, x="Age",y="Survived",errorbar=None)
# ----> 2 sns.figure(figsize(17,8))
#
# AttributeError: module 'seaborn' has no attribute 'figure'

# %% [markdown]
# Inference: Bar graph is plotted with Age on x-axis and Survived on y-axis.

# %% [markdown]
# **6. Joint Plot**

# %%
sns.jointplot(x="Age", y="Pclass", data=ds)

# %% [markdown]
# Inference: Joint plot with Age on x axis and Pclass on y-axis is plotted. This graph shows the Pclass preference of certain ages.

# %% [markdown]
# **7. Box Plot**

# %%
sns.boxplot(x="Survived",y="SibSp",data=ds)
# Out:
# <Axes: xlabel='Survived', ylabel='SibSp'>

# %% [markdown]
# Inference: Box plot with Survived on x axis and SibSp on y-axis is plotted.

# %% [markdown]
# # 5. Outlier Detection

# %%
sns.boxplot(ds.Fare)
# Out:
# <Axes: >

# %% [markdown]
# **Outlier replacement with median**

# %%
qu1=ds.Fare.quantile(0.25)
qu3=ds.Fare.quantile(0.75)
print(qu1)
print(qu3)
# Out:
# 7.9104
# 31.0

# %%
IQR=qu3-qu1
IQR
# Out:
# 23.0896

# %%
up_limit=qu3+1.5*IQR
up_limit
# Out:
# 65.6344

# %%
low_limit=qu1-1.5*IQR
IQR
# Out:
# 23.0896

# %%
ds.Fare.median()
# Out:
# 14.4542

# %%
ds['Fare']= np.where(ds['Fare']>up_limit,14.4542,ds['Fare'])
ds['Fare']
# Out:
# 0       7.2500
# 1      14.4542
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
sns.boxplot(ds.Fare)
# Out:
# <Axes: >

# %%
ds.shape  #No loss of data
# Out:
# (891, 12)

# %% [markdown]
# **Percentile**

# %%
per=ds.Fare.quantile(0.99)
per
# Out:
# 57.09792000000002

# %%
ds=ds[ds.Fare<=per]
sns.boxplot(ds.Fare)
# Out:
# <Axes: >

# %% [markdown]
# # 6. Splitting Dependent and Independent variables

# %%
#Independent Variables
x=ds.drop(columns=['Survived'], inplace=False)
x
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch            Ticket     Fare    Cabin  \
# 0      male  22.000000      1      0         A/5 21171   7.2500  B96 B98
# 1    female  38.000000      1      0          PC 17599  14.4542      C85
# 2    female  26.000000      0      0  STON/O2. 3101282   7.9250  B96 B98
# 3    female  35.000000      1      0            113803  53.1000     C123
# 4      male  35.000000      0      0            373450   8.0500  B96 B98
# ..      ...        ...    ...    ...               ...      ...      ...
# 886    male  27.000000      0      0            211536  13.0000  B96 B98
# 887  female  19.000000      0      0            112053  30.0000      B42
# 888  female  29.699118      1      2        W./C. 6607  23.4500  B96 B98
# 889    male  26.000000      0      0            111369  30.0000     C148
# 890    male  32.000000      0      0            370376   7.7500  B96 B98
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [882 rows x 11 columns]

# %%
#Dependent variable
y=ds.iloc[:,1:2]
y
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [882 rows x 1 columns]

# %%
ds.shape
# Out:
# (882, 12)

# %%
x.shape
# Out:
# (882, 11)

# %%
y.shape
# Out:
# (882, 1)

# %% [markdown]
# # 7. Encoding

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
x["Sex"]=l.fit_transform(x["Sex"])
x["Sex"]
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 882, dtype: int64

# %%
x.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#    Sex   Age  SibSp  Parch            Ticket     Fare    Cabin Embarked
# 0    1  22.0      1      0         A/5 21171   7.2500  B96 B98        S
# 1    0  38.0      1      0          PC 17599  14.4542      C85        C
# 2    0  26.0      0      0  STON/O2. 3101282   7.9250  B96 B98        S
# 3    0  35.0      1      0            113803  53.1000     C123        S
# 4    1  35.0      0      0            373450   8.0500  B96 B98        S

# %%
x["Sex"].value_counts()
# Out:
# 1    573
# 0    309
# Name: Sex, dtype: int64

# %%
x["Sex"].nunique()
# Out:
# 2

# %% [markdown]
# **Label Encoding on Embarked, Cabin & Ticket**

# %%
x["Embarked"]=l.fit_transform(x["Embarked"])
x["Embarked"]
# Out:
# 0      2
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 886    2
# 887    2
# 888    2
# 889    0
# 890    1
# Name: Embarked, Length: 882, dtype: int64

# %%
x["Embarked"].value_counts()
# Out:
# 2    643
# 0    162
# 1     77
# Name: Embarked, dtype: int64

# %%
x["Embarked"].nunique()
# Out:
# 3

# %%
x.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#    Sex   Age  SibSp  Parch            Ticket     Fare    Cabin  Embarked
# 0    1  22.0      1      0         A/5 21171   7.2500  B96 B98         2
# 1    0  38.0      1      0          PC 17599  14.4542      C85         0
# 2    0  26.0      0      0  STON/O2. 3101282   7.9250  B96 B98         2
# 3    0  35.0      1      0            113803  53.1000     C123         2
# 4    1  35.0      0      0            373450   8.0500  B96 B98         2

# %%
x["Ticket"]=l.fit_transform(x["Ticket"])
x["Ticket"]
# Out:
# 0      520
# 1      592
# 2      663
# 3       47
# 4      469
#       ...
# 886     99
# 887     13
# 888    669
# 889      7
# 890    463
# Name: Ticket, Length: 882, dtype: int64

# %%
x["Cabin"]=l.fit_transform(x["Cabin"])
x["Cabin"]
# Out:
# 0      45
# 1      79
# 2      45
# 3      53
# 4      45
#        ..
# 886    45
# 887    28
# 888    45
# 889    58
# 890    45
# Name: Cabin, Length: 882, dtype: int64

# %%
x["Name"]=l.fit_transform(x["Name"])
x["Name"]
# Out:
# 0      108
# 1      189
# 2      351
# 3      271
# 4       15
#       ...
# 886    542
# 887    302
# 888    407
# 889     81
# 890    219
# Name: Name, Length: 882, dtype: int64

# %%
x
# Out:
#      PassengerId  Pclass  Name  Sex        Age  SibSp  Parch  Ticket     Fare  \
# 0              1       3   108    1  22.000000      1      0     520   7.2500
# 1              2       1   189    0  38.000000      1      0     592  14.4542
# 2              3       3   351    0  26.000000      0      0     663   7.9250
# 3              4       1   271    0  35.000000      1      0      47  53.1000
# 4              5       3    15    1  35.000000      0      0     469   8.0500
# ..           ...     ...   ...  ...        ...    ...    ...     ...      ...
# 886          887       2   542    1  27.000000      0      0      99  13.0000
# 887          888       1   302    0  19.000000      0      0      13  30.0000
# 888          889       3   407    0  29.699118      1      2     669  23.4500
# 889          890       1    81    1  26.000000      0      0       7  30.0000
# 890          891       3   219    1  32.000000      0      0     463   7.7500
#
#      Cabin  Embarked
# 0       45         2
# 1       79         0
# 2       45         2
# 3       53         2
# 4       45         2
# ..     ...       ...
# 886     45         2
# 887     28         2
# 888     45         2
# 889     58         0
# 890     45         1
#
# [882 rows x 11 columns]

# %% [markdown]
# **Correlation after encoding**

# %%
corr=ds.corr()
corr
# Out:
# <ipython-input-61-5fb269adebca>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=ds.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.009548 -0.044338  0.038705 -0.060494 -0.002870
# Survived       -0.009548  1.000000 -0.338136 -0.069492 -0.035868  0.075182
# Pclass         -0.044338 -0.338136  1.000000 -0.325355  0.081677  0.025713
# Age             0.038705 -0.069492 -0.325355  1.000000 -0.235436 -0.186432
# SibSp          -0.060494 -0.035868  0.081677 -0.235436  1.000000  0.418549
# Parch          -0.002870  0.075182  0.025713 -0.186432  0.418549  1.000000
# Fare            0.016764  0.183125 -0.419194  0.032520  0.283286  0.284996
#
#                  Fare
# PassengerId  0.016764
# Survived     0.183125
# Pclass      -0.419194
# Age          0.032520
# SibSp        0.283286
# Parch        0.284996
# Fare         1.000000

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # 8. Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)
x_train
# Out:
# array([[-1.6948399 ,  0.85675649,  1.09700401, ..., -0.76182423,
#         -0.29079717,  0.59293918],
#        [-1.113136  , -0.33921354,  1.55529655, ..., -0.1248214 ,
#         -0.29079717,  0.59293918],
#        [-1.23416164,  0.85675649, -0.83326203, ..., -0.77458083,
#         -0.29079717, -1.93011926],
#        ...,
#        [ 0.74519324, -0.33921354, -1.03522145, ...,  0.74381884,
#         -0.29079717,  0.59293918],
#        [ 0.46800547,  0.85675649,  1.31838261, ..., -0.77458083,
#         -0.29079717,  0.59293918],
#        [ 0.95991616,  0.85675649,  0.02894936, ...,  3.24598252,
#         -0.29079717,  0.59293918]])

# %% [markdown]
# # 9. Splitting Data into Train and Test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((617, 11), (265, 11), (617, 1), (265, 1))
