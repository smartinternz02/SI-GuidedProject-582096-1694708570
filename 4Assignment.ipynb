# %% [markdown]
# # **Name: Gongati Sree Nidhitha Reddy**

# %% [markdown]
# ## Reg.No: 21BCE2409

# %% [markdown]
# # **1. Import necessary libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **2. Import Dataset**

# %%
ds=pd.read_csv("Employee-Attrition.csv")
ds
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
ds.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
ds.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
ds.shape
# Out:
# (1470, 35)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
ds.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
ds.Age.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       41.0
# 1       49.0
# 2       37.0
# 3       33.0
# 4       27.0
#         ...
# 1465    36.0
# 1466    39.0
# 1467    27.0
# 1468    49.0
# 1469    34.0
# Name: Age, Length: 1455, dtype: float64>

# %%
ds.EmployeeCount.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1465    1
# 1466    1
# 1467    1
# 1468    1
# 1469    1
# Name: EmployeeCount, Length: 1470, dtype: int64>

# %%
ds.HourlyRate.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       94
# 1       61
# 2       92
# 3       56
# 4       40
#         ..
# 1465    41
# 1466    42
# 1467    87
# 1468    63
# 1469    82
# Name: HourlyRate, Length: 1470, dtype: int64>

# %%
ds.YearsAtCompany.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        6
# 1       10
# 2        0
# 3        8
# 4        2
#         ..
# 1465     5
# 1466     7
# 1467     6
# 1468     9
# 1469     4
# Name: YearsAtCompany, Length: 1470, dtype: int64>

# %% [markdown]
# # **3. Data Preprocessing**

# %% [markdown]
# # a. Handling Null Values

# %%
ds.isnull().any()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# ...

# %%
ds.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
ds["Age"].fillna(ds["Age"].mean(),inplace=True)
ds
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
ds["Attrition"].fillna(ds["Attrition"].mode()[0],inplace=True)
ds["BusinessTravel"].fillna(ds["BusinessTravel"].mode()[0],inplace=True)
ds
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
ds.isnull().any()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# ...

# %% [markdown]
# # b. Data Visualization

# %% [markdown]
# **1. Scatter Plot**

# %%
sns.scatterplot(x="BusinessTravel", y="DailyRate", data=ds)
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='DailyRate'>

# %% [markdown]
# Inference: In the above graph BusinessTravel is taken on x-axis and DailyRate is taken on y-axis. This is to analize BusinessTravel at the DailyRate.

# %% [markdown]
# **2. Line Plot**

# %%
sns.lineplot(x="Age",y="Attrition",data=ds)
# Out:
# <Axes: xlabel='Age', ylabel='Attrition'>

# %% [markdown]
# Inference: In the above graph Age is taken on x-axis and Attrition is taken on y-axis. This plot analysis says that the Age and Attrition doesnot have a frequent and regular response.

# %% [markdown]
# **3. Distribution Plot**

# %%
sns.distplot(ds["DailyRate"])
# Out:
# <ipython-input-101-fadaadbee764>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ds["DailyRate"])
# <Axes: xlabel='DailyRate', ylabel='Density'>

# %% [markdown]
# Inference: In this graph x-axis represents DAilyRate  and y-axis represents the probability density. The density of DailyRateis steady from a 200-1500 and then gradually decreases.

# %% [markdown]
# **4. Relational plot**

# %%
sns.relplot(x="BusinessTravel", y="Attrition", data=ds, hue="Age")

# %% [markdown]
# Inference: Relational plot with BusinessTravel on x-axis and Attrition on y-axis with hue as Age is plotted. It allows us to visualise how variables on a dataset relate to each other.

# %% [markdown]
# **5. Bar Plot**

# %%
sns.barplot(data=ds, x="Department",y="DailyRate",errorbar=None)
sns.figure(figsize(17,8))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-c07182cf8f1e> in <cell line: 2>()
#       1 sns.barplot(data=ds, x="Department",y="DailyRate",errorbar=None)
# ----> 2 sns.figure(figsize(17,8))
#
# AttributeError: module 'seaborn' has no attribute 'figure'

# %% [markdown]
# Inference: Bar graph is plotted with Department on x-axis and dailyRate on y-axis.

# %% [markdown]
# **6. Joint Plot**

# %%
sns.jointplot(x="Age", y="Attrition", data=ds)

# %% [markdown]
# Inference: Joint plot with Age on x axis and Attrition on y-axis is plotted. This graph shows the Attrition preference of certain ages.

# %% [markdown]
# **7. Box Plot**

# %%
sns.boxplot(x="Education",y="HourlyRate",data=ds)
# Out:
# <Axes: xlabel='Education', ylabel='HourlyRate'>

# %% [markdown]
# Inference: Box plot with Education on x axis and Hourlyrate on y-axis is plotted.

# %% [markdown]
# # c. Outlier Detection

# %%
sns.boxplot(ds.Age)
# Out:
# <Axes: >

# %% [markdown]
# **Outlier replacement with median**

# %%
qu1=ds.Age.quantile(0.25)
qu3=ds.Age.quantile(0.75)
print(qu1)
print(qu3)
# Out:
# 30.0
# 43.0

# %%
IQR=qu3-qu1
IQR
# Out:
# 13.0

# %%
up_limit=qu3+1.5*IQR
up_limit
# Out:
# 62.5

# %%
low_limit=qu1-1.5*IQR
IQR
# Out:
# 13.0

# %%
ds.Age.median()
# Out:
# 36.0

# %%
ds['Age']= np.where(ds['Age']>up_limit,14.4542,ds['Age'])
ds['Age']
# Out:
# 0       41.0
# 1       49.0
# 2       37.0
# 3       33.0
# 4       27.0
#         ...
# 1465    36.0
# 1466    39.0
# 1467    27.0
# 1468    49.0
# 1469    34.0
# Name: Age, Length: 1470, dtype: float64

# %%
sns.boxplot(ds.Age)
# Out:
# <Axes: >

# %%
ds.shape  #No loss of data
# Out:
# (1470, 35)

# %% [markdown]
# **Percentile**

# %%
per=ds.Age.quantile(0.99)
per
# Out:
# 58.309999999999945

# %%
ds=ds[ds.Age<=per]
sns.boxplot(ds.Age)
# Out:
# <Axes: >

# %% [markdown]
# # d. Splitting Dependent and Independent variables

# %%
#Independent Variables
x=ds.drop(columns=['Attrition'], inplace=False)
x
# Out:
#        Age     BusinessTravel  DailyRate              Department  \
# 0     41.0      Travel_Rarely     1102.0                   Sales
# 1     49.0  Travel_Frequently      279.0  Research & Development
# 2     37.0      Travel_Rarely     1373.0  Research & Development
# 3     33.0  Travel_Frequently     1392.0  Research & Development
# 4     27.0      Travel_Rarely      591.0  Research & Development
# ...    ...                ...        ...                     ...
# 1465  36.0  Travel_Frequently      884.0  Research & Development
# 1466  39.0      Travel_Rarely      613.0  Research & Development
# 1467  27.0      Travel_Rarely      155.0  Research & Development
# 1468  49.0  Travel_Frequently     1023.0                   Sales
# 1469  34.0      Travel_Rarely      628.0  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# ...

# %%
#Dependent variable
y=ds.iloc[:,1:2]
y
# Out:
#      Attrition
# 0          Yes
# 1           No
# 2          Yes
# 3           No
# 4           No
# ...        ...
# 1465        No
# 1466        No
# 1467        No
# 1468        No
# 1469        No
#
# [1455 rows x 1 columns]

# %%
ds.shape
# Out:
# (1455, 35)

# %%
x.shape
# Out:
# (1455, 34)

# %%
y.shape
# Out:
# (1455, 1)

# %% [markdown]
# # e. Encoding

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
x["Gender"]=l.fit_transform(x["Gender"])
x["Gender"]
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1465    1
# 1466    1
# 1467    1
# 1468    1
# 1469    1
# Name: Gender, Length: 1455, dtype: int64

# %%
x.head()
# Out:
#     Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0  41.0               2        622           2                 1          2
# 1  49.0               1        113           1                 8          1
# 2  37.0               2        802           1                 2          2
# 3  33.0               1        817           1                 3          4
# 4  27.0               2        312           1                 2          1
#
#    EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 0               1              1               1                        2
# 1               1              1               2                        3
# 2               4              1               4                        4
# 3               1              1               5                        4
# 4               3              1               7                        1
#
# ...

# %%
x["Gender"].value_counts()
# Out:
# 1    875
# 0    580
# Name: Gender, dtype: int64

# %%
x["Gender"].nunique()
# Out:
# 2

# %% [markdown]
# **Label Encoding on JobRole, Over18, OverTime & MaritalStatus**

# %%
x["JobRole"]=l.fit_transform(x["JobRole"])
x["JobRole"]
# Out:
# 0       7
# 1       6
# 2       2
# 3       6
# 4       2
#        ..
# 1465    2
# 1466    0
# 1467    4
# 1468    7
# 1469    2
# Name: JobRole, Length: 1455, dtype: int64

# %%
x["JobRole"].value_counts()
# Out:
# 7    320
# 6    291
# 2    258
# 4    143
# 0    130
# 3     99
# 8     83
# 5     80
# 1     51
# Name: JobRole, dtype: int64

# %%
x["JobRole"].nunique()
# Out:
# 9

# %%
x.head()
# Out:
#     Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0  41.0               2        622           2                 1          2
# 1  49.0               1        113           1                 8          1
# 2  37.0               2        802           1                 2          2
# 3  33.0               1        817           1                 3          4
# 4  27.0               2        312           1                 2          1
#
#    EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 0               1              1               1                        2
# 1               1              1               2                        3
# 2               4              1               4                        4
# 3               1              1               5                        4
# 4               3              1               7                        1
#
# ...

# %%
x["MaritalStatus"]=l.fit_transform(x["MaritalStatus"])
x["MaritalStatus"]
# Out:
# 0       2
# 1       1
# 2       2
# 3       1
# 4       1
#        ..
# 1465    1
# 1466    1
# 1467    1
# 1468    1
# 1469    1
# Name: MaritalStatus, Length: 1455, dtype: int64

# %%
x["Over18"]=l.fit_transform(x["Over18"])
x["Over18"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Over18, Length: 1455, dtype: int64

# %%
x["OverTime"]=l.fit_transform(x["OverTime"])
x["OverTime"]
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    1
# 1468    0
# 1469    0
# Name: OverTime, Length: 1455, dtype: int64

# %%
x
# Out:
#        Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     41.0               2        622           2                 1
# 1     49.0               1        113           1                 8
# 2     37.0               2        802           1                 2
# 3     33.0               1        817           1                 3
# 4     27.0               2        312           1                 2
# ...    ...             ...        ...         ...               ...
# 1465  36.0               1        492           1                23
# 1466  39.0               2        327           1                 6
# 1467  27.0               2         39           1                 4
# 1468  49.0               1        577           2                 2
# 1469  34.0               2        336           1                 8
#
#       Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0             2               1              1               1
# ...

# %% [markdown]
# **Correlation after encoding**

# %%
corr=ds.corr()
corr
# Out:
# <ipython-input-134-5fb269adebca>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=ds.corr()
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.002268          0.001295   0.211464
# DailyRate                 0.002268   1.000000         -0.011358  -0.017182
# DistanceFromHome          0.001295  -0.011358          1.000000   0.019221
# Education                 0.211464  -0.017182          0.019221   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber            0.003901  -0.045641          0.033676   0.040155
# EnvironmentSatisfaction   0.019969   0.020298         -0.015768  -0.029656
# HourlyRate                0.024971   0.021423          0.026769   0.015944
# ...

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# xxxxxxx. Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()
x_train=ms.fit_transform(x_train)
x_test=ms.fit_transform(x_test)
x_train
# Out:
# array([[0.45      , 1.        , 0.59840728, ..., 0.44444444, 0.2       ,
#         0.52941176],
#        [0.15      , 0.5       , 0.20136519, ..., 0.        , 0.        ,
#         0.        ],
#        [0.6       , 1.        , 0.58020478, ..., 0.11111111, 0.        ,
#         0.11764706],
#        ...,
#        [0.7       , 1.        , 0.4516496 , ..., 0.38888889, 0.        ,
#         0.52941176],
#        [0.925     , 1.        , 0.4596132 , ..., 0.11111111, 0.06666667,
#         0.23529412],
#        [0.45      , 1.        , 0.30489192, ..., 0.38888889, 0.2       ,
#         0.41176471]])

# %% [markdown]
# # h. Splitting Data into Train and Test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1164, 34), (291, 34), (1164, 1), (291, 1))

# %% [markdown]
# # **4. Model Building and Performance metrics**

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
pred=model.predict(x_test)
pred
# Out:
# array(['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No',
#        'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes',
# ...

# %%
y_test
# Out:
#      Attrition
# 584         No
# 495        Yes
# 145         No
# 111        Yes
# 1238        No
# ...        ...
# 41          No
# 962         No
# 78          No
# 1451        No
# 1264        No
#
# [291 rows x 1 columns]

# %%
ds
# Out:
#        Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     41.0       Yes      Travel_Rarely     1102.0                   Sales
# 1     49.0        No  Travel_Frequently      279.0  Research & Development
# 2     37.0       Yes      Travel_Rarely     1373.0  Research & Development
# 3     33.0        No  Travel_Frequently     1392.0  Research & Development
# 4     27.0        No      Travel_Rarely      591.0  Research & Development
# ...    ...       ...                ...        ...                     ...
# 1465  36.0        No  Travel_Frequently      884.0  Research & Development
# 1466  39.0        No      Travel_Rarely      613.0  Research & Development
# 1467  27.0        No      Travel_Rarely      155.0  Research & Development
# 1468  49.0        No  Travel_Frequently     1023.0                   Sales
# 1469  34.0        No      Travel_Rarely      628.0  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# **Evaluation of classification model**

# %%
#Accuracy score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve
accuracy_score(y_test,pred)
# Out:
# 0.8247422680412371

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[227,  10],
#        [ 41,  13]])

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.85      0.96      0.90       237
#          Yes       0.57      0.24      0.34        54
#
#     accuracy                           0.82       291
#    macro avg       0.71      0.60      0.62       291
# weighted avg       0.79      0.82      0.79       291

# %%
probability=model.predict_proba(x_test)[:,1]
probability
# Out:
# array([1.66676219e-02, 6.63882117e-02, 5.69437719e-02, 4.40783737e-01,
#        2.68366417e-01, 5.10961218e-02, 2.65497117e-02, 9.74894849e-02,
#        5.90406818e-01, 4.31718917e-02, 3.76696783e-03, 2.09168426e-01,
#        1.93137411e-01, 4.98589700e-01, 4.53362656e-03, 6.76778362e-02,
#        4.83957519e-02, 2.04519170e-01, 8.34933364e-02, 2.18183002e-02,
#        4.70743012e-02, 4.87996212e-01, 5.45968775e-02, 1.45683542e-01,
#        8.06009770e-03, 1.83714242e-02, 1.52435370e-02, 9.23090699e-02,
#        8.53814019e-02, 1.15674719e-02, 4.66987389e-02, 4.70479106e-02,
#        3.89614793e-01, 4.85142217e-01, 1.40822206e-01, 4.28747117e-02,
#        3.26357437e-02, 7.98683894e-02, 3.48338957e-01, 4.67111520e-01,
#        5.52945450e-02, 6.82620702e-01, 1.55608163e-01, 2.29270148e-01,
#        5.73199251e-02, 2.29845422e-01, 5.69572295e-01, 4.21217881e-01,
#        1.21305147e-01, 6.83199199e-02, 3.57290456e-01, 2.01301105e-02,
# ...

# %% [markdown]
# # **Desicion Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=dtc.predict(x_test)
pred
# Out:
# array(['No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No',
#        'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No',
#        'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No',
#        'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No',
# ...

# %%
y_test
# Out:
#      Attrition
# 584         No
# 495        Yes
# 145         No
# 111        Yes
# 1238        No
# ...        ...
# 41          No
# 962         No
# 78          No
# 1451        No
# 1264        No
#
# [291 rows x 1 columns]

# %% [markdown]
# # **Hyper Prameter Tuning**

# %%
from sklearn import tree
plt.figure(figsize=(25,15))
tree.plot_tree(dtc,filled=True)
# Out:
# [Text(0.46317184418145957, 0.9736842105263158, 'x[21] <= 0.5\ngini = 0.265\nsamples = 1164\nvalue = [981, 183]'),
#  Text(0.13936143984220908, 0.9210526315789473, 'x[27] <= 0.038\ngini = 0.178\nsamples = 838\nvalue = [755, 83]'),
#  Text(0.04339250493096647, 0.868421052631579, 'x[11] <= 0.407\ngini = 0.453\nsamples = 52\nvalue = [34, 18]'),
#  Text(0.015779092702169626, 0.8157894736842105, 'x[1] <= 0.25\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(0.007889546351084813, 0.7631578947368421, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.023668639053254437, 0.7631578947368421, 'x[0] <= 0.362\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.015779092702169626, 0.7105263157894737, 'x[22] <= 0.893\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.007889546351084813, 0.6578947368421053, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.023668639053254437, 0.6578947368421053, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
# ...

# %%
from sklearn.model_selection import GridSearchCV
parameter={
    'criterion':['gini','entropy'],
    'splitter':['best','random'],
    'max_depth':[1,2,3,4,5],
    'max_features':['auto','sqrt','log2']
}
grid_search=GridSearchCV(estimator=dtc,param_grid=parameter,cv=5,scoring='accuracy')
grid_search.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# ...

# %%
grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 3,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
dtc_cv=DecisionTreeClassifier(criterion= 'gini',
                              max_depth= 5,
                              max_features='log2',
                              splitter='random')
dtc_cv.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, max_features='log2', splitter='random')

# %%
pred=dtc_cv.predict(x_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.82      0.98      0.89       237
#          Yes       0.33      0.04      0.07        54
#
#     accuracy                           0.81       291
#    macro avg       0.58      0.51      0.48       291
# weighted avg       0.73      0.81      0.74       291

# %% [markdown]
# # **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
forest_params=[{'max_depth': list(range(10,15)), 'max_features': list(range(0,14))}]
rfc_cv=GridSearchCV(rfc,param_grid=forest_params,cv=10,scoring="accuracy")
rfc_cv.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
pred=rfc_cv.predict(x_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.85      0.99      0.91       237
#          Yes       0.85      0.20      0.33        54
#
#     accuracy                           0.85       291
#    macro avg       0.85      0.60      0.62       291
# weighted avg       0.85      0.85      0.80       291

# %%
rfc_cv.best_params_
# Out:
# {'max_depth': 10, 'max_features': 10}
